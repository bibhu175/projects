# %%
import pandas as pd
temp=pd.read_csv('temp.csv')
temp.head()
# Out:
#          date    day    time   temp  activ
# 0  01-07-2019  307.0   930.0  36.58    NaN
# 1  02-07-2019  307.0   940.0  36.73    0.0
# 2  03-07-2019  307.0   950.0  36.93    0.0
# 3  04-07-2019  307.0  1000.0  37.15    NaN
# 4  05-07-2019  307.0  1010.0  37.23    0.0

# %%
temp.dropna(how="all")
temp.sum(axis=1)
# Out:
# 0      1273.58
# 1      1283.73
# 2      1293.93
# 3      1344.15
# 4      1354.23
# 5      1364.24
# 6      1374.24
# 7      1383.90
# 8      1393.95
# 9      1443.89
# 10     1453.95
# 11     1464.00
# 12     1473.90
# 13     1483.99
# 14     1493.99
# 15     1544.01
# 16     1554.04
# 17     1564.04
# 18     1574.14
# 19     1584.07
# 20     1593.98
# 21     1644.01
# 22     1653.97
# 23     1663.97
# 24     1674.12
# 25     1684.13
# 26     1694.14
# 27     1744.15
# 28     1754.17
# 29     1764.12
#         ...
# 71     2465.95
# 72     2475.76
# 73     2485.60
# 74     2495.89
# 75     2545.86
# 76     2555.71
# 77     2565.78
# 78     2575.82
# 79     2585.76
# 80     2595.81
# 81     2645.84
# 82     2656.01
# 83     2666.10
# 84     2676.15
# 85     2685.92
# 86     2695.64
# 87      346.70
# 88      356.46
# 89      366.41
# 90      376.46
# 91      386.56
# 92      396.55
# 93      446.75
# 94      456.76
# 95      466.73
# 96      476.77
# 97      487.01
# 98      497.04
# ...

# %%
temp.dropna(subset=['activ'])
# Out:
#           date    day    time   temp  activ
# 1   02-07-2019  307.0   940.0  36.73    0.0
# 2   03-07-2019  307.0   950.0  36.93    0.0
# 4   05-07-2019  307.0  1010.0  37.23    0.0
# 5   06-07-2019  307.0  1020.0  37.24    0.0
# 6   07-07-2019  307.0  1030.0  37.24    0.0
# 7   08-07-2019  307.0  1040.0  36.90    0.0
# 8   09-07-2019  307.0  1050.0  36.95    0.0
# 9   10-07-2019  307.0  1100.0  36.89    0.0
# 10  11-07-2019  307.0  1110.0  36.95    0.0
# 11  12-07-2019  307.0  1120.0  37.00    0.0
# 12  13-07-2019  307.0  1130.0  36.90    0.0
# 13  14-07-2019  307.0  1140.0  36.99    0.0
# 14  15-07-2019  307.0  1150.0  36.99    0.0
# 15  16-07-2019  307.0  1200.0  37.01    0.0
# 16  17-07-2019  307.0  1210.0  37.04    0.0
# 17  18-07-2019  307.0  1220.0  37.04    0.0
# 18  19-07-2019  307.0  1230.0  37.14    0.0
# 19  20-07-2019  307.0  1240.0  37.07    0.0
# 20  21-07-2019  307.0  1250.0  36.98    0.0
# 21  22-07-2019  307.0  1300.0  37.01    0.0
# ...

# %%
temp['activ'].fillna(0,inplace=True)
temp.tail()
# Out:
#            date    day   time   temp  activ
# 96   05-10-2019  308.0  130.0  37.77    1.0
# 97   06-10-2019  308.0  140.0  38.01    1.0
# 98   07-10-2019  308.0  150.0  38.04    1.0
# 99   08-10-2019  308.0  200.0  38.07    1.0
# 100         NaN    NaN    NaN    NaN    0.0

# %%
temp.sort_values('temp')
# Out:
#            date    day    time   temp  activ
# 0    01-07-2019  307.0   930.0  36.58    0.0
# 1    02-07-2019  307.0   940.0  36.73    0.0
# 9    10-07-2019  307.0  1100.0  36.89    0.0
# 12   13-07-2019  307.0  1130.0  36.90    0.0
# 7    08-07-2019  307.0  1040.0  36.90    0.0
# 2    03-07-2019  307.0   950.0  36.93    0.0
# 10   11-07-2019  307.0  1110.0  36.95    0.0
# 8    09-07-2019  307.0  1050.0  36.95    0.0
# 22   23-07-2019  307.0  1310.0  36.97    0.0
# 23   24-07-2019  307.0  1320.0  36.97    0.0
# 20   21-07-2019  307.0  1250.0  36.98    0.0
# 13   14-07-2019  307.0  1140.0  36.99    0.0
# 14   15-07-2019  307.0  1150.0  36.99    0.0
# 11   12-07-2019  307.0  1120.0  37.00    0.0
# 15   16-07-2019  307.0  1200.0  37.01    0.0
# 21   22-07-2019  307.0  1300.0  37.01    0.0
# 16   17-07-2019  307.0  1210.0  37.04    0.0
# 17   18-07-2019  307.0  1220.0  37.04    0.0
# 19   20-07-2019  307.0  1240.0  37.07    0.0
# 29   30-07-2019  307.0  1420.0  37.12    0.0
# ...

# %%
sale=pd.read_csv('sale.csv')
sale.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 1       Offline              C    7/5/2010  301644504  7/26/2010        2167
# 2       Offline              C   9/12/2011  478051030  9/29/2011        4778
# 3       Offline              L   5/13/2010  892599952  6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596  7/27/2015        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
sale.sort_values(['Region','Country'])
# Out:
#                   Region     Country        Item Type Sales Channel  \
# 422                 Asia  Bangladesh        Household       Offline
# 830                 Asia  Bangladesh           Fruits        Online
# 850                 Asia  Bangladesh          Clothes        Online
# 892                 Asia  Bangladesh           Snacks        Online
# 1065                Asia  Bangladesh  Office Supplies       Offline
# 1273                Asia  Bangladesh        Baby Food        Online
# 1643                Asia  Bangladesh           Fruits        Online
# 1703                Asia  Bangladesh        Baby Food        Online
# 1929                Asia  Bangladesh        Baby Food       Offline
# 2133                Asia  Bangladesh        Beverages       Offline
# 2337                Asia  Bangladesh             Meat        Online
# 2341                Asia  Bangladesh             Meat        Online
# 2590                Asia  Bangladesh        Cosmetics       Offline
# ...

# %%
sales=pd.read_csv('sale.csv').dropna(how='all')
sale['Total Profit']=sale['Total Profit'].fillna(0).astype(int)
sale['Total Profit'].rank(ascending=True).astype(int)
sale['Total Profit Rank']=sale['Total Profit'].rank(ascending=True).astype(int)
sale.sort_values('Total Profit',ascending=True)
# Out:
#                                  Region                           Country  \
# 664                       North America          United States of America
# 1435              Australia and Oceania                        East Timor
# 1457                             Europe                           Finland
# 1405                 Sub-Saharan Africa                            Rwanda
# 3284  Central America and the Caribbean            Saint Kitts and Nevis
# 3188                               Asia                           Vietnam
# 603                  Sub-Saharan Africa                           Senegal
# 3109                      North America                            Canada
# 582                                Asia                            Brunei
# 3024  Central America and the Caribbean                          Honduras
# 2244                             Europe            Bosnia and Herzegovina
# 4129                             Europe                           Iceland
# ...

# %%
df=pd.read_csv('salary.csv',index_col=['Emp ID'],squeeze=True)
df.head()
# Out:
#        Name Prefix First Name Middle Initial Last Name Gender  \
# Emp ID
# 677509        Drs.       Lois              H    Walker      F
# 940761         Ms.     Brenda              S  Robinson      F
# 428945         Dr.        Joe              W  Robinson      M
# 408351        Drs.      Diane              I     Evans      F
# 193819         Mr.   Benjamin              R   Russell      M
#
#                               E Mail     Father's Name       Mother's Name  \
# Emp ID
# 677509       lois.walker@hotmail.com     Donald Walker        Helen Walker
# 940761     brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 428945        joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
# 408351         diane.evans@yahoo.com       Jason Evans      Michelle Evans
# 193819  benjamin.russell@charter.net   Gregory Russell   Elizabeth Russell
#
#        Mother's Maiden Name Date of Birth  ...          SSN    Phone No.   \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 677509 to 495141
# Data columns (total 36 columns):
# Name Prefix               100 non-null object
# First Name                100 non-null object
# Middle Initial            100 non-null object
# Last Name                 100 non-null object
# Gender                    100 non-null object
# E Mail                    100 non-null object
# Father's Name             100 non-null object
# Mother's Name             100 non-null object
# Mother's Maiden Name      100 non-null object
# Date of Birth             100 non-null object
# Time of Birth             100 non-null object
# Age in Yrs.               100 non-null float64
# Weight in Kgs.            100 non-null int64
# Date of Joining           100 non-null object
# Quarter of Joining        100 non-null object
# Half of Joining           100 non-null object
# Year of Joining           100 non-null int64
# Month of Joining          100 non-null int64
# ...

# %%
pd.to_datetime(df[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\bibhuti\appdata\local\programs\python\python37\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1860         try:
# -> 1861             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1862             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-f60a4d78f487> in <module>
# ----> 1 pd.to_datetime(df[0])
#
# ...

# %%
df=pd.read_csv('sale.csv')
df.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 1       Offline              C    7/5/2010  301644504  7/26/2010        2167
# 2       Offline              C   9/12/2011  478051030  9/29/2011        4778
# 3       Offline              L   5/13/2010  892599952  6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596  7/27/2015        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
# Region            5000 non-null object
# Country           5000 non-null object
# Item Type         5000 non-null object
# Sales Channel     5000 non-null object
# Order Priority    5000 non-null object
# Order Date        5000 non-null object
# Order ID          5000 non-null int64
# Ship Date         5000 non-null object
# Units Sold        5000 non-null int64
# Unit Price        5000 non-null float64
# Unit Cost         5000 non-null float64
# Total Revenue     5000 non-null float64
# Total Cost        5000 non-null float64
# Total Profit      5000 non-null float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 547.0+ KB

# %%
df["Order Date"].head()
# Out:
# 0    12/20/2013
# 1      7/5/2010
# 2     9/12/2011
# 3     5/13/2010
# 4     7/20/2015
# Name: Order Date, dtype: object

# %%
pd.to_datetime(df["Order Date"]).head()
df["Order Date"]=pd.to_datetime(df["Order Date"])

# %%
df["Country"].head()
# Out:
# 0    Antigua and Barbuda
# 1                  Panama
# 2          Czech Republic
# 3             North Korea
# 4               Sri Lanka
# Name: Country, dtype: object

# %%
df=pd.read_csv('sale.csv')
df.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 1       Offline              C    7/5/2010  301644504  7/26/2010        2167
# 2       Offline              C   9/12/2011  478051030  9/29/2011        4778
# 3       Offline              L   5/13/2010  892599952  6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596  7/27/2015        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
mask1=df['Region']=='Asia'
mask2=df['Sales Channel']=='Online'
df[mask1 & mask2].head()
# Out:
#    Region     Country        Item Type Sales Channel Order Priority  \
# 42   Asia        Laos             Meat        Online              L
# 43   Asia  Kyrgyzstan           Snacks        Online              C
# 49   Asia      Taiwan        Baby Food        Online              M
# 51   Asia        Laos  Office Supplies        Online              H
# 85   Asia     Myanmar        Cosmetics        Online              C
#
#    Order Date   Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  \
# 42  3/21/2017  734708821  3/24/2017        5522      421.89     364.69
# 43   8/6/2013  727492606  9/22/2013          84      152.58      97.44
# 49  5/27/2014  369560611  6/13/2014          52      255.28     159.42
# 51  8/10/2012  197185981  9/11/2012         568      651.21     524.96
# 85  6/13/2014  657033336   7/2/2014        9620      437.20     263.33
#
#     Total Revenue  Total Cost  Total Profit
# 42     2329676.58  2013818.18     315858.40
# ...

# %%
mask3=df['Region']=='Asia'
mask4=df['Sales Channel']=='Online'
df[mask3 | mask4].head()
# Out:
#                               Region                 Country  Item Type  \
# 0  Central America and the Caribbean    Antigua and Barbuda   Baby Food
# 3                               Asia             North Korea     Cereal
# 4                               Asia               Sri Lanka     Snacks
# 7                             Europe  Bosnia and Herzegovina    Clothes
# 9                 Sub-Saharan Africa                Ethiopia  Baby Food
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 3       Offline              L   5/13/2010  892599952  6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596  7/27/2015        7542
# 7        Online              M  10/14/2013  919133651  11/4/2013         927
# 9        Online              M   4/13/2015  192993152   5/7/2015        9817
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df=pd.read_csv('sale.csv')
df
mask=df['Region'].isin(['Asia','Europe','Sub-Saharan Africa'])
df[mask].head()
# Out:
#                Region                 Country  Item Type Sales Channel  \
# 2              Europe          Czech Republic  Beverages       Offline
# 3                Asia             North Korea     Cereal       Offline
# 4                Asia               Sri Lanka     Snacks       Offline
# 7              Europe  Bosnia and Herzegovina    Clothes        Online
# 9  Sub-Saharan Africa                Ethiopia  Baby Food        Online
#
#   Order Priority  Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 2              C   9/12/2011  478051030  9/29/2011        4778       47.45
# 3              L   5/13/2010  892599952  6/15/2010        9016      205.70
# 4              C   7/20/2015  571902596  7/27/2015        7542      152.58
# 7              M  10/14/2013  919133651  11/4/2013         927      109.28
# 9              M   4/13/2015  192993152   5/7/2015        9817      255.28
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
mask=df['Region'].isnull()
df[mask]
# Out:
# Empty DataFrame
# Columns: [Region, Country, Item Type, Sales Channel, Order Priority, Order Date, Order ID, Ship Date, Units Sold, Unit Price, Unit Cost, Total Revenue, Total Cost, Total Profit]
# Index: []

# %%
mask1=df['Region'].notnull()
df[mask1]
# Out:
#                                  Region                           Country  \
# 0     Central America and the Caribbean              Antigua and Barbuda
# 1     Central America and the Caribbean                            Panama
# 2                                Europe                    Czech Republic
# 3                                  Asia                       North Korea
# 4                                  Asia                         Sri Lanka
# 5          Middle East and North Africa                           Morocco
# 6                 Australia and Oceania    Federated States of Micronesia
# 7                                Europe            Bosnia and Herzegovina
# 8          Middle East and North Africa                       Afghanistan
# 9                    Sub-Saharan Africa                          Ethiopia
# 10         Middle East and North Africa                            Turkey
# 11         Middle East and North Africa                              Oman
# ...

# %%
df=['Country'].between("7-5-2010","3-13-2017")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-3e327fcc1492> in <module>
# ----> 1 df=['Country'].between("7-5-2010","3-13-2017")
#
# AttributeError: 'list' object has no attribute 'between'
