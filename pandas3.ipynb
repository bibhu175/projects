# %%
import pandas as pd
df=pd.read_csv('sale.csv')
df.head()
df['Item Type'].duplicated(keep=False)
df[df['Item Type'].duplicated()]
# Out:
#                                  Region                           Country  \
# 4                                  Asia                         Sri Lanka
# 7                                Europe            Bosnia and Herzegovina
# 8          Middle East and North Africa                       Afghanistan
# 9                    Sub-Saharan Africa                          Ethiopia
# 12                                 Asia                          Malaysia
# 13    Central America and the Caribbean                       Saint Lucia
# 14    Central America and the Caribbean  Saint Vincent and the Grenadines
# 16                               Europe                           Austria
# 17                               Europe                          Bulgaria
# 18                        North America                            Mexico
# 19    Central America and the Caribbean               Trinidad and Tobago
# 20         Middle East and North Africa                             Libya
# ...

# %%
len(df)
#df.drop_duplicates(subset=['Region'], keep='first')
# Out:
# 5000

# %%
len(df.drop_duplicates(subset=['Region'], keep='first'))
# Out:
# 7

# %%
bond=pd.read_csv('jamesbond.csv')
bond.head()
# Out:
#                     Film  Year  Years lapse    Bond actor  \
# 0                 Dr. No  1962          NaN  Sean Connery
# 1  From Russia With Love  1963          1.0  Sean Connery
# 2             Goldfinger  1964          1.0  Sean Connery
# 3            Thunderball  1965          1.0  Sean Connery
# 4    You Only Live Twice  1967          2.0  Sean Connery
#
#    Bond actor appearance  Villians Dispatched  Others' Dispatched  \
# 0                      1                    4                   8
# 1                      2                   11                  16
# 2                      3                    9                  68
# 3                      4                   20                  90
# 4                      5                   21                 175
#
#    Total Dispatched  Adjusted box office  Actual box office  ...  \
# 0                12                448.8               59.5  ...
# 1                27                543.8               78.9  ...
# ...

# %%
bond.set_index('Film',inplace=True)
bond.head()
# Out:
#                        Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Dr. No                 1962          NaN  Sean Connery                      1
# From Russia With Love  1963          1.0  Sean Connery                      2
# Goldfinger             1964          1.0  Sean Connery                      3
# Thunderball            1965          1.0  Sean Connery                      4
# You Only Live Twice    1967          2.0  Sean Connery                      5
#
#                        Villians Dispatched  Others' Dispatched  \
# Film
# Dr. No                                   4                   8
# From Russia With Love                   11                  16
# Goldfinger                               9                  68
# Thunderball                             20                  90
# You Only Live Twice                     21                 175
#
#                        Total Dispatched  Adjusted box office  \
# Film
# ...

# %%
bond.loc['Moonraker']
# Out:
# Year                                       1979
# Years lapse                                   2
# Bond actor                          Roger Moore
# Bond actor appearance                         4
# Villians Dispatched                          12
# Others' Dispatched                           69
# Total Dispatched                             81
# Adjusted box office                         535
# Actual box office                         210.3
# Adjusted budget                            91.5
# Actual budget                                34
# Director                          Lewis Gilbert
# Rotten Tomatoes critic score                59%
# Rotten Tomatoes audience score              43%
# Golden Globe nominations                      0
# Golden Globe wins                             0
# Academy Award nominations                     1
# Academy Award wins                            0
# Number of Bond drinks                         7
# Bond girls                                    4
# ...

# %%
bond.loc['Moonraker','Bond actor']
# Out:
# 'Roger Moore'

# %%
bond.iloc[4]
# Out:
# Year                                       1967
# Years lapse                                   2
# Bond actor                         Sean Connery
# Bond actor appearance                         5
# Villians Dispatched                          21
# Others' Dispatched                          175
# Total Dispatched                            196
# Adjusted box office                       514.2
# Actual box office                           101
# Adjusted budget                            59.9
# Actual budget                              10.3
# Director                          Lewis Gilbert
# Rotten Tomatoes critic score                73%
# Rotten Tomatoes audience score              69%
# Golden Globe nominations                      0
# Golden Globe wins                             0
# Academy Award nominations                     0
# Academy Award wins                            0
# Number of Bond drinks                       9.5
# Bond girls                                    4
# ...

# %%
bond.iloc[2:8]
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# Goldfinger                       1964          1.0    Sean Connery
# Thunderball                      1965          1.0    Sean Connery
# You Only Live Twice              1967          2.0    Sean Connery
# On Her Majesty's Secret Service  1969          2.0  George Lazenby
# Diamonds Are Forever             1971          2.0    Sean Connery
# Live and Let Die                 1973          2.0     Roger Moore
#
#                                  Bond actor appearance  Villians Dispatched  \
# Film
# Goldfinger                                           3                    9
# Thunderball                                          4                   20
# You Only Live Twice                                  5                   21
# On Her Majesty's Secret Service                      1                    5
# Diamonds Are Forever                                 6                    7
# ...

# %%
bond.iloc[14,2:8]
# Out:
# Bond actor               Timothy Dalton
# Bond actor appearance                 1
# Villians Dispatched                  13
# Others' Dispatched                   29
# Total Dispatched                     42
# Adjusted box office               313.5
# Name: The Living Daylights, dtype: object

# %%
bond.ix[20,'Director']
# Out:
# c:\users\bibhuti\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 'Martin Campbell'

# %%
bond.ix["Dr. No"]
# Out:
# c:\users\bibhuti\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                                           1962
# Years lapse                                     NaN
# Bond actor                         Sir Sean Connery
# Bond actor appearance                             1
# Villians Dispatched                               4
# Others' Dispatched                                8
# Total Dispatched                                 12
# Adjusted box office                           448.8
# Actual box office                              59.5
# Adjusted budget                                   7
# Actual budget                                   1.1
# ...

# %%
bond.ix["Dr. No","Bond actor"]="Sir Sean Connery"
# Out:
# c:\users\bibhuti\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
bond.ix["Bond actor"]
# Out:
# c:\users\bibhuti\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\bibhuti\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
bond.ix["Dr. No",["Adjusted box office","Adjusted budget","Actual budget"]]=[470,9,2]
# Out:
# c:\users\bibhuti\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
bond.ix["Dr. No"]
# Out:
# c:\users\bibhuti\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                                           1962
# Years lapse                                     NaN
# Bond actor                         Sir Sean Connery
# Bond actor appearance                             1
# Villians Dispatched                               4
# Others' Dispatched                                8
# Total Dispatched                                 12
# Adjusted box office                             470
# Actual box office                              59.5
# Adjusted budget                                   9
# Actual budget                                     2
# ...

# %%
mask=bond["Bond actor"]== "Sir Sean Connery"
bond.ix[mask]
# Out:
# c:\users\bibhuti\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#         Year  Years lapse        Bond actor  Bond actor appearance  \
# Film
# Dr. No  1962          NaN  Sir Sean Connery                      1
#
#         Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# Dr. No                    4                   8                12
#
#         Adjusted box office  Actual box office  Adjusted budget  ...  \
# Film                                                             ...
# Dr. No                470.0               59.5              9.0  ...
#
#         Academy Award nominations Academy Award wins Number of Bond drinks  \
# Film
# ...

# %%
bond.sample(frac=0.50)
# Out:
#                                  Year  Years lapse        Bond actor  \
# Film
# Octopussy                        1983          2.0       Roger Moore
# For Your Eyes Only               1981          2.0       Roger Moore
# GoldenEye                        1995          6.0    Pierce Brosnan
# The Living Daylights             1987          2.0    Timothy Dalton
# Casino Royale                    2006          4.0      Daniel Craig
# The Man with the Golden Gun      1974          1.0       Roger Moore
# Dr. No                           1962          NaN  Sir Sean Connery
# Quantum of Solace                2008          2.0      Daniel Craig
# On Her Majesty's Secret Service  1969          2.0    George Lazenby
# Goldfinger                       1964          1.0      Sean Connery
# You Only Live Twice              1967          2.0      Sean Connery
# Tomorrow Never Dies              1997          2.0    Pierce Brosnan
#
# ...

# %%
bond.sample(n=3,axis=1)
# Out:
#                                  Year  Academy Award nominations  \
# Film
# Dr. No                           1962                          0
# From Russia With Love            1963                          0
# Goldfinger                       1964                          1
# Thunderball                      1965                          1
# You Only Live Twice              1967                          0
# On Her Majesty's Secret Service  1969                          0
# Diamonds Are Forever             1971                          1
# Live and Let Die                 1973                          1
# The Man with the Golden Gun      1974                          0
# The Spy Who Loved Me             1977                          3
# Moonraker                        1979                          1
# For Your Eyes Only               1981                          1
# Octopussy                        1983                          0
# ...

# %%
bond.where(bond["Adjusted box office"]>800)
# Out:
#                                    Year  Years lapse    Bond actor  \
# Film
# Dr. No                              NaN          NaN           NaN
# From Russia With Love               NaN          NaN           NaN
# Goldfinger                       1964.0          1.0  Sean Connery
# Thunderball                      1965.0          1.0  Sean Connery
# You Only Live Twice                 NaN          NaN           NaN
# On Her Majesty's Secret Service     NaN          NaN           NaN
# Diamonds Are Forever                NaN          NaN           NaN
# Live and Let Die                    NaN          NaN           NaN
# The Man with the Golden Gun         NaN          NaN           NaN
# The Spy Who Loved Me                NaN          NaN           NaN
# Moonraker                           NaN          NaN           NaN
# For Your Eyes Only                  NaN          NaN           NaN
# Octopussy                           NaN          NaN           NaN
# ...
